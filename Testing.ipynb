# %%
import pickle
from bertopic import BERTopic
import numpy as np
import pandas as pd
import xgboost as xgb


testing_df = pd.read_feather('test.feather')

topic_model = BERTopic.load('TopicModel')

xg = xgb.XGBClassifier()
xg.load_model('xgboost_model.json')

# %%
testing_df.dropna(subset=['videoID'], inplace=True)

n = 5
testing_df['combined_text'] = [' '.join(testing_df['text'].iloc[i:i+n+1]) for i in range(len(testing_df))]
testing_df['expected'] = [np.mean(testing_df['sponsored'].iloc[i:i+n+1]) for i in range(len(testing_df))]
texts = testing_df['combined_text'].tolist()
expected = testing_df['sponsored'].astype(int).tolist()

# %%
topics = topic_model.transform(texts)[1]
# Out:
# Batches:   0%|          | 0/36924 [00:00<?, ?it/s]
# 2025-04-04 20:08:49,098 - BERTopic - Predicting topic assignments through cosine similarity of topic and document embeddings.

# %%
from sklearn.metrics import root_mean_squared_error

y_pred_prob = xg.predict_proba(topics)[:, 1]  # Get probability of positive class
threshold = 0.3  # Reduce threshold to classify more positives
y_pred = (y_pred_prob > threshold).astype(int)  # Convert probabilities to labels
rmse = root_mean_squared_error(expected, y_pred)  # RMSE
print(f"RMSE: {rmse:.4f}")
# Out:
# RMSE: 0.2701

# %%
testing_df['prediction'] = y_pred
testing_df['prediction_raw'] = y_pred_prob

# %%
testing_df
# Out:
#              videoID                                               UUID  \
# 807      --bcgPU87Hk  661fb9820d57f249502270489a6c8532442a9e9c205e45...
# 808      --bcgPU87Hk  661fb9820d57f249502270489a6c8532442a9e9c205e45...
# 809      --bcgPU87Hk  661fb9820d57f249502270489a6c8532442a9e9c205e45...
# 810      --bcgPU87Hk                                               None
# 811      --bcgPU87Hk                                               None
# ...              ...                                                ...
# 5837851  zzVwq6T5xo0  af202ba338583ffc82b7ec43ef59c84581071466206398...
# 5837852  zzVwq6T5xo0  af202ba338583ffc82b7ec43ef59c84581071466206398...
# 5837853  zzVwq6T5xo0  af202ba338583ffc82b7ec43ef59c84581071466206398...
# 5837854  zzVwq6T5xo0                                               None
# 5837855  zzVwq6T5xo0                                               None
#
#         category   start  duration                                     text  \
# 807      sponsor    0.03     2.820       this video sponsored by sheets and
# 808      sponsor    1.50     3.990   giggles more on them at the end of the
# 809      sponsor    2.85     3.390      sketch hey hey man hey hey you look
# 810      sponsor    5.49     2.369                                different
# 811      sponsor    6.24     3.029         oh yeah yeah see im actually not
# ...          ...     ...       ...                                      ...
# 5837851  sponsor  784.37     2.580  it always hooks the layman and well see
# 5837852  sponsor  785.78     3.620                       you guys next time
# 5837853  sponsor  786.95     2.450                               leymah nap
# 5837854  sponsor  790.88    15.149                                    music
# 5837855  sponsor  803.97     2.059                                      you
#
#          sponsored           text_without_stopwords  \
# 807           True           video sponsored sheets
# 808           True                      giggles end
# 809           True  sketch hey hey man hey hey look
# 810          False                        different
# 811          False     oh yeah yeah see im actually
# ...            ...                              ...
# 5837851       True     always hooks layman well see
# 5837852       True                   guys next time
# 5837853       True                       leymah nap
# 5837854      False                            music
# 5837855      False
#
#                                              combined_text  expected  \
# 807      this video sponsored by sheets and giggles mor...  0.500000
# 808      giggles more on them at the end of the sketch ...  0.333333
# 809      sketch hey hey man hey hey you look different ...  0.166667
# 810      different oh yeah yeah see im actually not cov...  0.000000
# 811      oh yeah yeah see im actually not covered in fi...  0.000000
# ...                                                    ...       ...
# 5837851  it always hooks the layman and well see you gu...  0.600000
# 5837852            you guys next time leymah nap music you  0.500000
# 5837853                               leymah nap music you  0.333333
# 5837854                                          music you  0.000000
# 5837855                                                you  0.000000
#
#          prediction  prediction_raw
# 807               0        0.125202
# 808               0        0.005730
# 809               0        0.220844
# 810               0        0.181572
# 811               0        0.010176
# ...             ...             ...
# 5837851           0        0.022876
# 5837852           0        0.031211
# 5837853           0        0.041813
# 5837854           0        0.050317
# 5837855           0        0.040780
#
# [1181551 rows x 12 columns]

# %%
subset_df = pd.read_feather('llm_results_with_deepseek.feather')
texts = subset_df['combined_text'].tolist()
expected = subset_df['sponsored'].astype(int).tolist()
topics = topic_model.transform(texts)[1]
# Out:
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# 2025-04-04 20:08:53,512 - BERTopic - Predicting topic assignments through cosine similarity of topic and document embeddings.

# %%
y_pred_prob = xg.predict_proba(topics)[:, 1]  # Get probability of positive class
threshold = 0.3  # Reduce threshold to classify more positives
y_pred = (y_pred_prob > threshold).astype(int)  # Convert probabilities to labels
rmse = root_mean_squared_error(expected, y_pred)  # RMSE
print(f"RMSE: {rmse:.4f}")
# Out:
# RMSE: 0.5385

# %%
subset_df['xg_prediction'] = y_pred.astype(bool)
subset_df['xg_prediction_raw'] = y_pred_prob

# %%
subset_df
# Out:
#          videoID                                               UUID category  \
# 0    th_KQOeh-Co  db67f847cbf9593e5dd0643f4ffaf91ebdee8263a1c56b...  sponsor
# 1    5VWTfXfm47g  f0801d6cffddc590a7732fdb0270fd8d73143ce4146320...  sponsor
# 2    A0Lkh02_Ik4                                               None  sponsor
# 3    sRrEkZ8OqiQ                                               None  sponsor
# 4    5_3BUU9ZmNo                                               None  sponsor
# ..           ...                                                ...      ...
# 195  6HKI35P-m-w  437c57864759f62683d9851603566f4d8a98ff6167f570...  sponsor
# 196  wYWGf2rKTCY  89630073f16e6ab44c414d1557c4e7c467eec05033bf2f...  sponsor
# 197  oTtYPB5h47E  08a89748af8d746ce205e765091813fa1296db8371661f...  sponsor
# 198  17oZPYcpPnQ  6cf9b637e525869d190dc86875245563f5aaf77ab860cd...  sponsor
# 199  MyhgEfTBzfc                                               None  sponsor
#
#        start  duration                                               text  \
# 0      7.880     5.509       welcome welcome everyone and congratulations
# 1    300.639     3.521                again thank you to trade coffee for
# 2    777.740     3.810              havent seen gigging like that since i
# 3    455.509     3.480               its gone boom and its gone it doesnt
# 4    610.060     3.709  if you could just add more hotbar slots it\nwo...
# ..       ...       ...                                                ...
# 195  192.540     4.650                verve just by going to verve co  to
# 196  602.000     5.120                by design a guide to elevating your
# 197  620.740     3.570             the charges can either show up as what
# 198    0.599     2.421          this video was made possible by brilliant
# 199  211.599     4.351               actually want to grow there and like
#
#      sponsored                            text_without_stopwords  \
# 0         True          welcome welcome everyone congratulations
# 1         True                                thank trade coffee
# 2        False                    havent seen gigging like since
# 3        False                             gone boom gone doesnt
# 4        False  could add hotbar slots would cut way amount time
# ..         ...                                               ...
# 195       True                              verve going verve co
# 196       True                            design guide elevating
# 197       True                               charges either show
# 198       True                     video made possible brilliant
# 199      False                           actually want grow like
#
#                                          combined_text  expected  ...  \
# 0    welcome welcome everyone and congratulations i...  0.166667  ...
# 1    again thank you to trade coffee for sponsoring...  0.333333  ...
# 2    havent seen gigging like that since i was a fr...  0.000000  ...
# 3    its gone boom and its gone it doesnt tell me i...  0.000000  ...
# 4    if you could just add more hotbar slots it\nwo...  0.000000  ...
# ..                                                 ...       ...  ...
# 195  verve just by going to verve co  to jacksfilms...  1.000000  ...
# 196  by design a guide to elevating your drawing sk...  1.000000  ...
# 197  the charges can either show up as what actuall...  1.000000  ...
# 198  this video was made possible by brilliant lear...  0.500000  ...
# 199  actually want to grow there and like leave spa...  0.000000  ...
#
#     granite-3.2-8b-instruct_One_Shot granite-3.2-8b-instruct_CARP-LESS  \
# 0                               True                              True
# 1                               True                              True
# 2                              False                             False
# 3                               True                             False
# 4                              False                             False
# ..                               ...                               ...
# 195                             True                             False
# 196                             True                             False
# 197                             True                             False
# 198                             True                             False
# 199                            False                             False
#
#      gemma-3-27b-it_Zero_Shot gemma-3-27b-it_One_Shot  \
# 0                        True                    True
# 1                        True                    True
# 2                        True                   False
# 3                        True                    True
# 4                        True                   False
# ..                        ...                     ...
# 195                      True                    True
# 196                      True                   False
# 197                      True                   False
# 198                      True                    True
# 199                      True                   False
#
#     gemma-3-27b-it_CARP-LESS  deepseek-r1-distill-qwen-7b_Zero_Shot  \
# 0                       True                                   True
# 1                       True                                   True
# 2                      False                                   True
# 3                      False                                   True
# 4                      False                                  False
# ..                       ...                                    ...
# 195                     True                                   True
# 196                     True                                   True
# 197                    False                                   True
# 198                     True                                   True
# 199                    False                                   True
#
#      deepseek-r1-distill-qwen-7b_One_Shot  \
# 0                                    True
# 1                                    True
# 2                                   False
# 3                                    True
# 4                                   False
# ..                                    ...
# 195                                  True
# 196                                  True
# 197                                 False
# 198                                  True
# 199                                 False
#
#      deepseek-r1-distill-qwen-7b_CARP-LESS  xg_prediction  xg_prediction_raw
# 0                                     True           True           0.894055
# 1                                    False          False           0.011293
# 2                                     True          False           0.011425
# 3                                     True           True           0.320752
# 4                                    False          False           0.006862
# ..                                     ...            ...                ...
# 195                                   True          False           0.136493
# 196                                  False          False           0.069150
# 197                                  False          False           0.209666
# 198                                   True          False           0.034510
# 199                                  False          False           0.114129
#
# [200 rows x 27 columns]

# %%
subset_df = subset_df.drop(['videoID', 'UUID', 'category', 'text_without_stopwords'], axis=1)
subset_df
# Out:
#        start  duration                                               text  \
# 0      7.880     5.509       welcome welcome everyone and congratulations
# 1    300.639     3.521                again thank you to trade coffee for
# 2    777.740     3.810              havent seen gigging like that since i
# 3    455.509     3.480               its gone boom and its gone it doesnt
# 4    610.060     3.709  if you could just add more hotbar slots it\nwo...
# ..       ...       ...                                                ...
# 195  192.540     4.650                verve just by going to verve co  to
# 196  602.000     5.120                by design a guide to elevating your
# 197  620.740     3.570             the charges can either show up as what
# 198    0.599     2.421          this video was made possible by brilliant
# 199  211.599     4.351               actually want to grow there and like
#
#      sponsored                                      combined_text  expected  \
# 0         True  welcome welcome everyone and congratulations i...  0.166667
# 1         True  again thank you to trade coffee for sponsoring...  0.333333
# 2        False  havent seen gigging like that since i was a fr...  0.000000
# 3        False  its gone boom and its gone it doesnt tell me i...  0.000000
# 4        False  if you could just add more hotbar slots it\nwo...  0.000000
# ..         ...                                                ...       ...
# 195       True  verve just by going to verve co  to jacksfilms...  1.000000
# 196       True  by design a guide to elevating your drawing sk...  1.000000
# 197       True  the charges can either show up as what actuall...  1.000000
# 198       True  this video was made possible by brilliant lear...  0.500000
# 199      False  actually want to grow there and like leave spa...  0.000000
#
#     hermes-3-llama-3.2-3b_Zero_Shot hermes-3-llama-3.2-3b_One_Shot  \
# 0                              True                           True
# 1                              True                           True
# 2                              True                          False
# 3                              None                          False
# 4                              True                          False
# ..                              ...                            ...
# 195                           False                           None
# 196                            True                           None
# 197                           False                          False
# 198                            True                          False
# 199                            True                          False
#
#      hermes-3-llama-3.2-3b_CARP-LESS meta-llama-3.1-8b-instruct_Zero_Shot  \
# 0                              False                                 True
# 1                              False                                 True
# 2                              False                                 None
# 3                              False                                 None
# 4                              False                                 None
# ..                               ...                                  ...
# 195                            False                                 None
# 196                            False                                 True
# 197                            False                                False
# 198                            False                                False
# 199                            False                                 None
#
#      ... granite-3.2-8b-instruct_One_Shot  granite-3.2-8b-instruct_CARP-LESS  \
# 0    ...                             True                               True
# 1    ...                             True                               True
# 2    ...                            False                              False
# 3    ...                             True                              False
# 4    ...                            False                              False
# ..   ...                              ...                                ...
# 195  ...                             True                              False
# 196  ...                             True                              False
# 197  ...                             True                              False
# 198  ...                             True                              False
# 199  ...                            False                              False
#
#      gemma-3-27b-it_Zero_Shot  gemma-3-27b-it_One_Shot  \
# 0                        True                     True
# 1                        True                     True
# 2                        True                    False
# 3                        True                     True
# 4                        True                    False
# ..                        ...                      ...
# 195                      True                     True
# 196                      True                    False
# 197                      True                    False
# 198                      True                     True
# 199                      True                    False
#
#      gemma-3-27b-it_CARP-LESS  deepseek-r1-distill-qwen-7b_Zero_Shot  \
# 0                        True                                   True
# 1                        True                                   True
# 2                       False                                   True
# 3                       False                                   True
# 4                       False                                  False
# ..                        ...                                    ...
# 195                      True                                   True
# 196                      True                                   True
# 197                     False                                   True
# 198                      True                                   True
# 199                     False                                   True
#
#      deepseek-r1-distill-qwen-7b_One_Shot  \
# 0                                    True
# 1                                    True
# 2                                   False
# 3                                    True
# 4                                   False
# ..                                    ...
# 195                                  True
# 196                                  True
# 197                                 False
# 198                                  True
# 199                                 False
#
#      deepseek-r1-distill-qwen-7b_CARP-LESS xg_prediction xg_prediction_raw
# 0                                     True          True          0.894055
# 1                                    False         False          0.011293
# 2                                     True         False          0.011425
# 3                                     True          True          0.320752
# 4                                    False         False          0.006862
# ..                                     ...           ...               ...
# 195                                   True         False          0.136493
# 196                                  False         False          0.069150
# 197                                  False         False          0.209666
# 198                                   True         False          0.034510
# 199                                  False         False          0.114129
#
# [200 rows x 23 columns]

# %%
testing_df = testing_df.drop(['videoID', 'UUID', 'category', 'text_without_stopwords'], axis=1)
testing_df
# Out:
#           start  duration                                     text  sponsored  \
# 807        0.03     2.820       this video sponsored by sheets and       True
# 808        1.50     3.990   giggles more on them at the end of the       True
# 809        2.85     3.390      sketch hey hey man hey hey you look       True
# 810        5.49     2.369                                different      False
# 811        6.24     3.029         oh yeah yeah see im actually not      False
# ...         ...       ...                                      ...        ...
# 5837851  784.37     2.580  it always hooks the layman and well see       True
# 5837852  785.78     3.620                       you guys next time       True
# 5837853  786.95     2.450                               leymah nap       True
# 5837854  790.88    15.149                                    music      False
# 5837855  803.97     2.059                                      you      False
#
#                                              combined_text  expected  \
# 807      this video sponsored by sheets and giggles mor...  0.500000
# 808      giggles more on them at the end of the sketch ...  0.333333
# 809      sketch hey hey man hey hey you look different ...  0.166667
# 810      different oh yeah yeah see im actually not cov...  0.000000
# 811      oh yeah yeah see im actually not covered in fi...  0.000000
# ...                                                    ...       ...
# 5837851  it always hooks the layman and well see you gu...  0.600000
# 5837852            you guys next time leymah nap music you  0.500000
# 5837853                               leymah nap music you  0.333333
# 5837854                                          music you  0.000000
# 5837855                                                you  0.000000
#
#          prediction  prediction_raw
# 807               0        0.125202
# 808               0        0.005730
# 809               0        0.220844
# 810               0        0.181572
# 811               0        0.010176
# ...             ...             ...
# 5837851           0        0.022876
# 5837852           0        0.031211
# 5837853           0        0.041813
# 5837854           0        0.050317
# 5837855           0        0.040780
#
# [1181551 rows x 8 columns]

# %%
testing_df.to_feather('xg_results.feather')
subset_df.to_feather('subset_full_results.feather')

# %%
testing_df['sponsored'].value_counts()
# Out:
# sponsored
# False    1111801
# True       69750
# Name: count, dtype: int64

# %%
69750/1111801
# Out:
# 0.06273604718830078
